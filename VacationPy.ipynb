# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# !pip install cartopy geoviews pyproj

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0   blackmans bay -43.0167  147.3167      8.07        93          60
# 1        1         cabinda  -5.5500   12.2000     28.08        89          96
# 2        2          hwange -18.3693   26.5019     23.23        72          39
# 3        3  puerto natales -51.7236  -72.4875      8.25        61          75
# 4        4        qaqortoq  60.7167  -46.0333     -9.38        87          20
#
#    Wind Speed Country        Date
# 0        0.45      AU  1710535957
# 1        1.54      AO  1710535961
# 2        2.55      ZW  1710535964
# 3        8.75      CL  1710535967
# 4        0.51      GL  1710535971

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
plot_map = city_data_df.hvplot.points(
        "Lng",
         "Lat",
         size= "Humidity",
    geo = True,
    scale=1,
     frame_width = 800,
frame_height = 600,
tiles = "OSM",
color = "City")
       


     

# Display the map
plot_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
narrowed_city_data_df=(city_data_df["Max Temp"]<27) 
    
# Drop any rows with null values
# narrowed_city_data_df.dropna(inplace+True)

# Display sample data
narrowed_city_data_df
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 543     True
# 544     True
# 545     True
# 546     True
# 547     True
# Name: Max Temp, Length: 548, dtype: bool

# %%
city_data_df[city_data_df["Max Temp"]>21]
# Out:
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 1          1            cabinda  -5.5500   12.2000     28.08        89
# 2          2             hwange -18.3693   26.5019     23.23        72
# 7          7  armacao de buzios -22.7469  -41.8817     29.09        90
# 10        10  bikenibeu village   1.3673  173.1241     28.98        84
# 12        12            anahuac  27.2333 -100.1500     35.41        27
# ..       ...                ...      ...       ...       ...       ...
# 541      541             pangai -19.8000 -174.3500     27.15        85
# 542      542           al jabin  14.7040   43.5990     23.91        51
# 544      544         carutapera  -1.1950  -46.0200     25.21        92
# 545      545             dukhan  25.4297   50.7858     21.58        65
# 546      546   minas de marcona -15.2119  -75.1103     21.28        69
#
#      Cloudiness  Wind Speed Country        Date
# 1            96        1.54      AO  1710535961
# ...

# %%
city_data_df.loc[((city_data_df['Max Temp'] < 27) & (city_data_df['Max Temp'] >21))]
#city_data_df.loc[((city_data_df['Max Temp']<27  ))]
# Out:
#      City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 2          2            hwange -18.3693   26.5019     23.23        72
# 15        15          enewetak  11.3474  162.3373     26.35        79
# 27        27        fort bragg  35.1390  -79.0060     21.85        71
# 30        30      richards bay -28.7830   32.0377     22.68        80
# 32        32          tangalle   6.0240   80.7911     25.33        86
# ..       ...               ...      ...       ...       ...       ...
# 538      538            noumea -22.2763  166.4572     26.67        99
# 542      542          al jabin  14.7040   43.5990     23.91        51
# 544      544        carutapera  -1.1950  -46.0200     25.21        92
# 545      545            dukhan  25.4297   50.7858     21.58        65
# 546      546  minas de marcona -15.2119  -75.1103     21.28        69
#
#      Cloudiness  Wind Speed Country        Date
# 2            39        2.55      ZW  1710535964
# ...

# %%
city_data_df[city_data_df["Wind Speed"]>4.5]
# Out:
#      City_ID                         City      Lat       Lng  Max Temp  \
# 3          3               puerto natales -51.7236  -72.4875      8.25
# 6          6                      ushuaia -54.8000  -68.3000      6.79
# 7          7            armacao de buzios -22.7469  -41.8817     29.09
# 9          9  edinburgh of the seven seas -37.0676  -12.3116     16.94
# 10        10            bikenibeu village   1.3673  173.1241     28.98
# ..       ...                          ...      ...       ...       ...
# 536      536                      vorkuta  67.5000   64.0000     -3.95
# 538      538                       noumea -22.2763  166.4572     26.67
# 541      541                       pangai -19.8000 -174.3500     27.15
# 546      546             minas de marcona -15.2119  -75.1103     21.28
# 547      547                    gold camp  33.2937 -111.3043     11.51
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# ...

# %%
city_data_df[city_data_df["Cloudiness"] ==0 ]
# Out:
#      City_ID                        City      Lat       Lng  Max Temp  \
# 7          7           armacao de buzios -22.7469  -41.8817     29.09
# 24        24                   tahlequah  35.9154  -94.9700     17.27
# 29        29                     kashgar  39.4547   75.9797      5.56
# 39        39                port lincoln -34.7333  135.8667     17.55
# 61        61                       pisco -13.7000  -76.2167     28.03
# 67        67               alice springs -23.7000  133.8833     18.75
# 68        68                    luderitz -26.6481   15.1594     16.91
# 69        69                      hasaki  35.7333  140.8333      9.22
# 70        70               morehead city  34.7229  -76.7260     24.03
# 79        79                   tataouine  32.9297   10.4518     14.27
# 90        90                   al qusayr  34.5091   36.5798      9.64
# 92        92                       dhuri  30.3667   75.8667     12.47
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
hotel_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[['City','Country','Lat','Lng','Humidity',]].copy()
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = None
#Display hotel_df DataFrame
print(hotel_df.head())
# Out:
#              City Country      Lat       Lng  Humidity Hotel Name
# 0   blackmans bay      AU -43.0167  147.3167        93       None
# 1         cabinda      AO  -5.5500   12.2000        89       None
# 2          hwange      ZW -18.3693   26.5019        72       None
# 3  puerto natales      CL -51.7236  -72.4875        61       None
# 4        qaqortoq      GL  60.7167  -46.0333        87       None

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
categories = "accomodation.hotel"

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    Latitude = row["Lat"]
    longitude = row["Lng"]
    
    
def get_lat_lon(city):
    city = row["City"]
    latitude,longitude = get_Lat_Lng(City)
    city_data_df.loc[index,"Latitude"] = Lat
    city_data_df.loc[index,"Longitude"] = Lng  
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude,}{latitude}"
    limit = 20
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = request.get(base_url,params=params)
    
    # Convert the API response to JSON format
    name_address = response.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
#                  City Country      Lat       Lng  Humidity Hotel Name
# 0       blackmans bay      AU -43.0167  147.3167        93       None
# 1             cabinda      AO  -5.5500   12.2000        89       None
# 2              hwange      ZW -18.3693   26.5019        72       None
# 3      puerto natales      CL -51.7236  -72.4875        61       None
# 4            qaqortoq      GL  60.7167  -46.0333        87       None
# ..                ...     ...      ...       ...       ...        ...
# 543     mammoth lakes      US  37.6485 -118.9721        50       None
# 544        carutapera      BR  -1.1950  -46.0200        92       None
# 545            dukhan      QA  25.4297   50.7858        65       None
# 546  minas de marcona      PE -15.2119  -75.1103        69       None
# 547         gold camp      US  33.2937 -111.3043        71       None
#
# [548 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Create a dictionary containing coordinates

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
     "Lng",
      "Lat",
        geo = True,
        tiles = "OSM",
      frame_width = 800,
      frame_height = 600,
      size = "Distance",
      scale = 0.5,
    color = "City"
)

map_plot
# Display the map# Assuming you have a DataFrame called city_data_df with the required data
# city_data_df should contain columns like 'City', 'Country', 'Latitude', 'Longitude', 'Humidity'

# Create a copy of the city_data_df DataFrame with selected columns
hotel_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Display the first few rows of the hotel_df DataFrame to verify the data
print(hotel_df.head())
# Out:
#              City Country      Lat       Lng  Humidity
# 0   blackmans bay      AU -43.0167  147.3167        93
# 1         cabinda      AO  -5.5500   12.2000        89
# 2          hwange      ZW -18.3693   26.5019        72
# 3  puerto natales      CL -51.7236  -72.4875        61
# 4        qaqortoq      GL  60.7167  -46.0333        87
